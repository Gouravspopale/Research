# %% [markdown]
# # About Dataset

# %% [markdown]
# The World's Top Military Strength Dataset is a comprehensive compilation of data gathered from various reliable sources, providing a detailed analysis and comparison of the military capabilities of countries worldwide. This dataset serves as a valuable resource for policymakers, researchers, defense analysts, and military enthusiasts, enabling them to assess and understand the relative strength and capacities of different nations' armed forces.

# %% [markdown]
# The World's Top Military Strength Dataset is continually updated and expanded to incorporate the latest information and developments. Users can benefit from the dataset's dynamic nature, staying informed about changes in military capabilities and staying up to date with emerging trends and technologies.

# %%
import pandas as pd
# loading data from csv file(read_csv) 
data=pd.read_csv("C:/Users/91843/Desktop/Research/Dataset/army-total-world.csv")
data
# Out:
#            country  activeDuty  paramilitary  reserves    total  \
# 0            China     2185000        660000   1170000  4015000
# 1            India     1455550       2526950   1155000  5137500
# 2    United States     1388100             0    844950  2233050
# 3      North Korea     1280000       5889000    600000  7769000
# 4           Russia     1014000        554000   2000000  3568000
# ..             ...         ...           ...       ...      ...
# 163          Haiti         150            50         0      200
# 164        Iceland           0           250         0      250
# 165      Mauritius           0          2550         0     2550
# 166     Costa Rica           0          9800         0     9800
# 167         Panama           0         26000         0    26000
#
#      population2022
# 0       1448471.400
# 1       1406631.776
# 2        334805.269
# 3         25990.679
# 4        145805.947
# ..              ...
# 163       11680.283
# 164         345.393
# ...

# %%
print(data.to_string())
# Out:
#                       country  activeDuty  paramilitary  reserves     total  population2022
# 0                       China     2185000        660000   1170000   4015000     1448471.400
# 1                       India     1455550       2526950   1155000   5137500     1406631.776
# 2               United States     1388100             0    844950   2233050      334805.269
# 3                 North Korea     1280000       5889000    600000   7769000       25990.679
# 4                      Russia     1014000        554000   2000000   3568000      145805.947
# 5                    Pakistan      654000        291000    550000   1495000      229488.994
# 6                        Iran      610000         40000    350000   1000000       86022.837
# 7                 South Korea      599000       3013500   3100000   6712500       51329.899
# 8                     Vietnam      482000       5040000   5000000  10522000       98953.541
# ...

# %%
print(data.head())
# Out:
#          country  activeDuty  paramilitary  reserves    total  population2022
# 0          China     2185000        660000   1170000  4015000     1448471.400
# 1          India     1455550       2526950   1155000  5137500     1406631.776
# 2  United States     1388100             0    844950  2233050      334805.269
# 3    North Korea     1280000       5889000    600000  7769000       25990.679
# 4         Russia     1014000        554000   2000000  3568000      145805.947

# %%
print(data.tail())
# Out:
#         country  activeDuty  paramilitary  reserves  total  population2022
# 163       Haiti         150            50         0    200       11680.283
# 164     Iceland           0           250         0    250         345.393
# 165   Mauritius           0          2550         0   2550        1274.727
# 166  Costa Rica           0          9800         0   9800        5182.354
# 167      Panama           0         26000         0  26000        4446.964

# %%
print(data.describe())
# Out:
#          activeDuty  paramilitary      reserves         total  population2022
# count  1.680000e+02  1.680000e+02  1.680000e+02  1.680000e+02    1.680000e+02
# mean   1.199320e+05  1.437658e+05  1.494214e+05  4.131192e+05    4.713149e+04
# std    2.733041e+05  6.704519e+05  5.244440e+05  1.272817e+06    1.601753e+05
# min    0.000000e+00  0.000000e+00  0.000000e+00  2.000000e+02    9.942600e+01
# 25%    9.412500e+03  0.000000e+00  0.000000e+00  1.441250e+04    4.300066e+03
# 50%    2.732500e+04  5.400000e+03  4.000000e+01  5.745000e+04    1.118101e+04
# 75%    1.233250e+05  3.131250e+04  5.270000e+04  2.521250e+05    3.454340e+04
# max    2.185000e+06  5.889000e+06  5.000000e+06  1.052200e+07    1.448471e+06

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         168 non-null    object
#  1   activeDuty      168 non-null    int64
#  2   paramilitary    168 non-null    int64
#  3   reserves        168 non-null    int64
#  4   total           168 non-null    int64
#  5   population2022  168 non-null    float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 8.0+ KB
# None

# %%
print(data.count())
# Out:
# country           168
# activeDuty        168
# paramilitary      168
# reserves          168
# total             168
# population2022    168
# dtype: int64

# %%
print(data.max())
# Out:
# country            Zimbabwe
# activeDuty          2185000
# paramilitary        5889000
# reserves            5000000
# total              10522000
# population2022    1448471.4
# dtype: object

# %%
print(data.min())
# Out:
# country           Afghanistan
# activeDuty                  0
# paramilitary                0
# reserves                    0
# total                     200
# population2022         99.426
# dtype: object

# %%
'''memory_usage() returns a Pandas Series having the memory usage of each column (in bytes) in a Pandas DataFrame.
By specifying the deep attribute as True, we can get to know the actual space being taken by each column'''

print(data.memory_usage())
# Out:
# Index              132
# country           1344
# activeDuty        1344
# paramilitary      1344
# reserves          1344
# total             1344
# population2022    1344
# dtype: int64

# %%
''' loc[:] helps to access a group of rows and columns in a dataset, a slice of the dataset, as per our requirement.
For instance, if we only want the last 2 rows and the first 3 columns of a dataset, we can access them with the help of loc[:].
We can also access rows and columns based on labels instead of row and column number.'''

print(data.loc[0:4,['country','paramilitary','reserves']])
# Out:
#          country  paramilitary  reserves
# 0          China        660000   1170000
# 1          India       2526950   1155000
# 2  United States             0    844950
# 3    North Korea       5889000    600000
# 4         Russia        554000   2000000

# %%
'''value_counts() returns a Pandas Series containing the counts of unique values. 
Consider a dataset that contains customer information about 5,000 customers of a company.
value_counts() will help us in identifying the number of occurrences of each unique value in a Series.
It can be applied to columns containing data like State, Industry of employment, or age of customers.'''

print(data.value_counts())
# Out:
# country      activeDuty  paramilitary  reserves  total    population2022
# Afghanistan  178800      99000         0         277800   40754.388         1
# Pakistan     654000      291000        550000    1495000  229488.994        1
# New Zealand  9000        0             2300      11300    4898.203          1
# Nicaragua    12000       0             0         12000    6779.100          1
# Niger        5300        5400          0         10700    26083.660         1
#                                                                            ..
# Germany      183500      0             30050     213550   83883.596         1
# Ghana        15500       0             0         15500    32395.450         1
# Greece       142700      4000          221350    368050   10316.637         1
# Guatemala    18050       25000         63850     106900   18584.039         1
# Zimbabwe     29000       21800         0         50800    15331.428         1
# Name: count, Length: 168, dtype: int64

# %%
'''drop_duplicates() returns a Pandas DataFrame with duplicate rows removed. 
Even among duplicates, there is an option to keep the first occurrence (record) of the duplicate or the last. 
You can also specify the inplace and ignore_index attribute'''

print(data.drop_duplicates())
# Out:
#            country  activeDuty  paramilitary  reserves    total  \
# 0            China     2185000        660000   1170000  4015000
# 1            India     1455550       2526950   1155000  5137500
# 2    United States     1388100             0    844950  2233050
# 3      North Korea     1280000       5889000    600000  7769000
# 4           Russia     1014000        554000   2000000  3568000
# ..             ...         ...           ...       ...      ...
# 163          Haiti         150            50         0      200
# 164        Iceland           0           250         0      250
# 165      Mauritius           0          2550         0     2550
# 166     Costa Rica           0          9800         0     9800
# 167         Panama           0         26000         0    26000
#
#      population2022
# 0       1448471.400
# 1       1406631.776
# 2        334805.269
# 3         25990.679
# 4        145805.947
# ..              ...
# 163       11680.283
# 164         345.393
# ...

# %% [markdown]
# # About Dataset

# %% [markdown]
# List of Army personnel in the world, and the population of the respective country.

# %%
import pandas as pd
# loading data from csv file(read_csv) 
data=pd.read_csv("C:/Users/User7/Desktop/Research/Dataset/List_of_countries_by_number_of_military_and_paramilitary_personnel_2023.csv")
data
# Out:
#                  Country Active military Reserve military Paramilitary  \
# 0            Afghanistan         250,000           75,000      170,000
# 1                Albania           8,000                0            0
# 2                Algeria         130,000          150,000      187,200
# 3                 Angola         107,000                0       10,000
# 4    Antigua and Barbuda             180               80            0
# ..                   ...             ...              ...          ...
# 167            Venezuela         123,000            8,000      220,000
# 168              Vietnam         482,000        5,000,000       40,000
# 169                Yemen          40,000                0            0
# 170               Zambia          15,100            3,000        1,400
# 171             Zimbabwe          29,000                0       21,800
#
#          Total  Per 1,000 capita\n(total)  Per 1,000 capita\n(active)
# ...
